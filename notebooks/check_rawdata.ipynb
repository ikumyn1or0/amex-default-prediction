# %% [markdown]
# # Preparation

# %% [markdown]
# ## import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Setting Notebook Parameters

# %%
MAX_DISPLAY_COLUMNS = 200
MAX_DISPLAY_ROWS = 200
# pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', MAX_DISPLAY_COLUMNS) 
pd.set_option('display.max_rows', MAX_DISPLAY_ROWS)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploring Train Data

# %%
train_sample = pd.read_csv("../input/train_data_sample.csv", nrows=100000)
train_sample.head()
# Out:
#    Unnamed: 0                                        customer_ID         S_2  \
# 0           0  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-03-09
# 1           1  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-04-07
# 2           2  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-05-28
# 3           3  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-06-13
# 4           4  0000099d6bd597052cdcda90ffabf56573fe9d7c79be5f...  2017-07-16
#
#         P_2      D_39       B_1       B_2       R_1       S_3      D_41  \
# 0  0.938469  0.001733  0.008724  1.006838  0.009228  0.124035  0.008771
# 1  0.936665  0.005775  0.004923  1.000653  0.006151  0.126750  0.000798
# 2  0.954180  0.091505  0.021655  1.009672  0.006815  0.123977  0.007598
# 3  0.960384  0.002455  0.013683  1.002700  0.001373  0.117169  0.000685
# 4  0.947248  0.002483  0.015193  1.000727  0.007605  0.117325  0.004653
#
# ...

# %%
print(f"rows (sampled): {train_sample.shape[0]}")
print(f"duplicated rows: {train_sample.duplicated().sum()}")
print(f"columns: {train_sample.shape[1]}")
# Out:
# rows (sampled): 100000
# duplicated rows: 0
# columns: 191

# %%
train_info = pd.DataFrame(data=train_sample.dtypes, index=train_sample.columns, columns=["dtypes"])
train_info["count"] = train_sample.count()
train_info["NAs"] = train_sample.isna().sum()
train_info["length"] = train_info["count"] + train_info["NAs"]
train_info["nunique"] = train_sample.nunique()
train_info
# Out:
#               dtypes   count    NAs  length  nunique
# Unnamed: 0     int64  100000      0  100000   100000
# customer_ID   object  100000      0  100000     8294
# S_2           object  100000      0  100000      396
# P_2          float64   99214    786  100000    99214
# D_39         float64  100000      0  100000   100000
# B_1          float64  100000      0  100000   100000
# B_2          float64   99963     37  100000    99963
# R_1          float64  100000      0  100000   100000
# S_3          float64   81374  18626  100000    81374
# D_41         float64   99963     37  100000    99963
# B_3          float64   99963     37  100000    99963
# D_42         float64   14614  85386  100000    14614
# D_43         float64   69805  30195  100000    69805
# D_44         float64   94947   5053  100000    94947
# B_4          float64  100000      0  100000   100000
# D_45         float64   99963     37  100000    99963
# B_5          float64  100000      0  100000   100000
# ...

# %% [markdown]
# ## [WIP]check column

# %%
features = ["B_", "D_", "P_", "R_", "S_"]
feature = features[3]
columns = list(train_sample.columns)
check_columns = [feature+str(int(c[2:])) for c in columns if feature in c]
print(check_columns)
# Out:
# ['R_1', 'R_2', 'R_3', 'R_4', 'R_5', 'R_6', 'R_7', 'R_8', 'R_9', 'R_10', 'R_11', 'R_12', 'R_13', 'R_14', 'R_15', 'R_16', 'R_17', 'R_18', 'R_19', 'R_20', 'R_21', 'R_22', 'R_23', 'R_24', 'R_25', 'R_26', 'R_27', 'R_28']

# %%
# column = "D_65"
column = check_columns[22]
print(column)
print(f"NAs: {train_sample[column].isna().sum()}")
figure = plt.figure(figsize=(25, 10))
ax1 = figure.add_subplot(2, 1, 1)
sns.histplot(data=train_sample, x=column, bins=100)
ax2 = figure.add_subplot(2, 1, 2)
xlim = [0, train_sample[column].max()/10]
# xlim = [0., 0.26]
sns.histplot(data=train_sample[["customer_ID", column]].query(f"{xlim[0]} <= {column} <= {xlim[1]}"), x=column, bins=1000)
plt.xlim(xlim)
plt.ylim([0, 100])
# Out:
# R_23
# NAs: 0
# (0.0, 100.0)

# %%
print(train_sample[column].min())
print(train_sample[column].max())
# Out:
# 1.1949530768773366e-07
# 1.009401844256515

# %%
data = np.round(train_sample[column]*1*2)
print(data.min())
print(data.max())
# print(data.mean())
# print(data.std())
print(data.value_counts())
# Out:
# 0.0
# 2.0
# 0.0    99953
# 2.0       47
# Name: R_23, dtype: int64
